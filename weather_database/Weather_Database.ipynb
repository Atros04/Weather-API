# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
from citipy import citipy
import time
import sys
sys.path.append("..")

# Import my API Key
from config import w_key

# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={w_key}"

# %%
lats = np.random.uniform(-90,90, size=2000)
lons = np.random.uniform(-180,180,size=2000)
coordinates = zip(lats,lons)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lon": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_descrip,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | esperance
# Processing Record 2 of Set 1 | fez
# Processing Record 3 of Set 1 | walvis bay
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | tshikapa
# Processing Record 6 of Set 1 | ketchikan
# Processing Record 7 of Set 1 | leningradskiy
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | estreito
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | zabol
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | bangassou
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | atar
# Processing Record 16 of Set 1 | rockhampton
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | sakakah
# Processing Record 19 of Set 1 | airai
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | souillac
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | sisimiut
# Processing Record 27 of Set 1 | wattegama
# Processing Record 28 of Set 1 | obo
# Processing Record 29 of Set 1 | lasa
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | kinablangan
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | asfi
# Processing Record 38 of Set 1 | port blair
# Processing Record 39 of Set 1 | harwich
# Processing Record 40 of Set 1 | constitucion
# Processing Record 41 of Set 1 | yenagoa
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | california city
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | sorland
# Processing Record 46 of Set 1 | mayor pablo lagerenza
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | kirkenes
# Processing Record 49 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 50 of Set 1 | isangel
# Processing Record 1 of Set 2 | guerrero negro
# Processing Record 2 of Set 2 | lavrentiya
# Processing Record 3 of Set 2 | invermere
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | alice springs
# Processing Record 6 of Set 2 | lakatoro
# Processing Record 7 of Set 2 | veinticinco de mayo
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | chokurdakh
# Processing Record 10 of Set 2 | vanimo
# Processing Record 11 of Set 2 | havre-saint-pierre
# Processing Record 12 of Set 2 | bondoukou
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | brewster
# Processing Record 15 of Set 2 | pinheiro
# Processing Record 16 of Set 2 | nishihara
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | byron bay
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | darab
# Processing Record 22 of Set 2 | kutum
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | whitianga
# Processing Record 25 of Set 2 | rajampet
# Processing Record 26 of Set 2 | kendari
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | alvorada
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | namibe
# Processing Record 32 of Set 2 | nushki
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | vila franca do campo
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | sangar
# Processing Record 37 of Set 2 | kulhudhuffushi
# Processing Record 38 of Set 2 | meulaboh
# Processing Record 39 of Set 2 | mnogovershinnyy
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | busselton
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | sorong
# Processing Record 46 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 2 | ahipara
# Processing Record 48 of Set 2 | tawnat
# City not found. Skipping...
# Processing Record 49 of Set 2 | broome
# Processing Record 50 of Set 2 | kavieng
# Processing Record 1 of Set 3 | coahuayana
# Processing Record 2 of Set 3 | port macquarie
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 3 | aswan
# Processing Record 6 of Set 3 | vaini
# Processing Record 7 of Set 3 | barcelos
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | bilibino
# Processing Record 11 of Set 3 | harper
# Processing Record 12 of Set 3 | klaksvik
# Processing Record 13 of Set 3 | praia da vitoria
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | zlitan
# Processing Record 16 of Set 3 | makat
# Processing Record 17 of Set 3 | necochea
# Processing Record 18 of Set 3 | anadyr
# Processing Record 19 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 3 | winslow
# Processing Record 21 of Set 3 | calama
# Processing Record 22 of Set 3 | ust-nera
# Processing Record 23 of Set 3 | sobolevo
# Processing Record 24 of Set 3 | gweta
# Processing Record 25 of Set 3 | usinsk
# Processing Record 26 of Set 3 | chuy
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | atbasar
# Processing Record 29 of Set 3 | neiafu
# Processing Record 30 of Set 3 | sile
# Processing Record 31 of Set 3 | loikaw
# Processing Record 32 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 3 | price
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | chara
# Processing Record 38 of Set 3 | alvaraes
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | sao filipe
# Processing Record 41 of Set 3 | hobart
# Processing Record 42 of Set 3 | svetlogorsk
# Processing Record 43 of Set 3 | presidencia roque saenz pena
# Processing Record 44 of Set 3 | athabasca
# Processing Record 45 of Set 3 | upernavik
# Processing Record 46 of Set 3 | auki
# Processing Record 47 of Set 3 | mount hagen
# Processing Record 48 of Set 3 | severo-kurilsk
# Processing Record 49 of Set 3 | aykhal
# Processing Record 50 of Set 3 | toul
# Processing Record 1 of Set 4 | sinnamary
# Processing Record 2 of Set 4 | mana
# Processing Record 3 of Set 4 | puerto ayora
# Processing Record 4 of Set 4 | nanortalik
# Processing Record 5 of Set 4 | marsh harbour
# Processing Record 6 of Set 4 | andra
# Processing Record 7 of Set 4 | merrill
# Processing Record 8 of Set 4 | kitimat
# Processing Record 9 of Set 4 | zhob
# Processing Record 10 of Set 4 | bredasdorp
# Processing Record 11 of Set 4 | saint quentin
# City not found. Skipping...
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | barrow
# Processing Record 15 of Set 4 | lompoc
# Processing Record 16 of Set 4 | udachnyy
# Processing Record 17 of Set 4 | roma
# Processing Record 18 of Set 4 | muros
# Processing Record 19 of Set 4 | caravelas
# Processing Record 20 of Set 4 | athens
# Processing Record 21 of Set 4 | nhulunbuy
# Processing Record 22 of Set 4 | yulara
# Processing Record 23 of Set 4 | balykshi
# Processing Record 24 of Set 4 | narsaq
# Processing Record 25 of Set 4 | cusset
# Processing Record 26 of Set 4 | boca do acre
# Processing Record 27 of Set 4 | adet
# Processing Record 28 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 4 | calebasses
# Processing Record 30 of Set 4 | vardo
# Processing Record 31 of Set 4 | batetskiy
# Processing Record 32 of Set 4 | cam ranh
# Processing Record 33 of Set 4 | dingle
# Processing Record 34 of Set 4 | marrakesh
# Processing Record 35 of Set 4 | waipawa
# Processing Record 36 of Set 4 | tyukhtet
# Processing Record 37 of Set 4 | fierze
# City not found. Skipping...
# Processing Record 38 of Set 4 | port alfred
# Processing Record 39 of Set 4 | seymchan
# Processing Record 40 of Set 4 | hambantota
# Processing Record 41 of Set 4 | paucartambo
# City not found. Skipping...
# Processing Record 42 of Set 4 | torata
# Processing Record 43 of Set 4 | cap malheureux
# Processing Record 44 of Set 4 | hithadhoo
# Processing Record 45 of Set 4 | porto novo
# Processing Record 46 of Set 4 | ust-kuyga
# Processing Record 47 of Set 4 | sao felix do xingu
# Processing Record 48 of Set 4 | roald
# Processing Record 49 of Set 4 | smirnykh
# Processing Record 50 of Set 4 | ostrovnoy
# Processing Record 1 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 5 | ambatofinandrahana
# Processing Record 3 of Set 5 | grand-santi
# Processing Record 4 of Set 5 | iqaluit
# Processing Record 5 of Set 5 | katsuura
# Processing Record 6 of Set 5 | hervey bay
# Processing Record 7 of Set 5 | balaipungut
# Processing Record 8 of Set 5 | lagoa
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | pevek
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | tiksi
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | husavik
# Processing Record 15 of Set 5 | mahebourg
# Processing Record 16 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 5 | andrews
# Processing Record 18 of Set 5 | kathmandu
# Processing Record 19 of Set 5 | george town
# Processing Record 20 of Set 5 | hualmay
# Processing Record 21 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 5 | bengkulu
# Processing Record 23 of Set 5 | biltine
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | la paz
# Processing Record 26 of Set 5 | luanda
# Processing Record 27 of Set 5 | zhaotong
# Processing Record 28 of Set 5 | lodja
# Processing Record 29 of Set 5 | tasiilaq
# Processing Record 30 of Set 5 | texarkana
# Processing Record 31 of Set 5 | korla
# Processing Record 32 of Set 5 | hofn
# Processing Record 33 of Set 5 | avarua
# Processing Record 34 of Set 5 | los llanos de aridane
# Processing Record 35 of Set 5 | nome
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | chitral
# Processing Record 38 of Set 5 | rio gallegos
# Processing Record 39 of Set 5 | katima mulilo
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | nova aurora
# Processing Record 42 of Set 5 | upington
# Processing Record 43 of Set 5 | chapulhuacan
# Processing Record 44 of Set 5 | nantucket
# Processing Record 45 of Set 5 | kupang
# Processing Record 46 of Set 5 | chiredzi
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | santiago del estero
# Processing Record 49 of Set 5 | yinchuan
# Processing Record 50 of Set 5 | cockburn town
# Processing Record 1 of Set 6 | verkhnevilyuysk
# Processing Record 2 of Set 6 | bow island
# Processing Record 3 of Set 6 | vostok
# Processing Record 4 of Set 6 | linhares
# Processing Record 5 of Set 6 | beringovskiy
# Processing Record 6 of Set 6 | bambanglipuro
# Processing Record 7 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 6 | jiuquan
# Processing Record 10 of Set 6 | takoradi
# Processing Record 11 of Set 6 | nagato
# Processing Record 12 of Set 6 | leeton
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | rehoboth
# Processing Record 15 of Set 6 | nikolayevsk-na-amure
# Processing Record 16 of Set 6 | quatre cocos
# Processing Record 17 of Set 6 | rio claro
# Processing Record 18 of Set 6 | andilamena
# Processing Record 19 of Set 6 | samur
# Processing Record 20 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 6 | owando
# Processing Record 22 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 6 | qostanay
# Processing Record 24 of Set 6 | iquitos
# Processing Record 25 of Set 6 | bandarbeyla
# Processing Record 26 of Set 6 | tommot
# Processing Record 27 of Set 6 | pisco
# Processing Record 28 of Set 6 | iralaya
# Processing Record 29 of Set 6 | ponta do sol
# Processing Record 30 of Set 6 | tambura
# Processing Record 31 of Set 6 | burnie
# Processing Record 32 of Set 6 | olovyannaya
# Processing Record 33 of Set 6 | ozernovskiy
# Processing Record 34 of Set 6 | bambous virieux
# Processing Record 35 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 6 | ulu-telyak
# Processing Record 37 of Set 6 | lagunas
# Processing Record 38 of Set 6 | ixtapa
# Processing Record 39 of Set 6 | fernandina beach
# Processing Record 40 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 6 | chokwe
# Processing Record 42 of Set 6 | niagara falls
# Processing Record 43 of Set 6 | ithaca
# Processing Record 44 of Set 6 | mandera
# Processing Record 45 of Set 6 | santa lucia
# Processing Record 46 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 6 | diosjeno
# Processing Record 48 of Set 6 | cayenne
# Processing Record 49 of Set 6 | krasnoselkup
# Processing Record 50 of Set 6 | znin
# Processing Record 1 of Set 7 | yar-sale
# Processing Record 2 of Set 7 | beira
# Processing Record 3 of Set 7 | alta floresta
# Processing Record 4 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 5 of Set 7 | hetauda
# Processing Record 6 of Set 7 | brae
# Processing Record 7 of Set 7 | soyo
# Processing Record 8 of Set 7 | mehran
# Processing Record 9 of Set 7 | saint andrews
# Processing Record 10 of Set 7 | jalu
# Processing Record 11 of Set 7 | haapiti
# Processing Record 12 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 7 | matay
# Processing Record 14 of Set 7 | grand gaube
# Processing Record 15 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 7 | goderich
# Processing Record 17 of Set 7 | ojinaga
# Processing Record 18 of Set 7 | veraval
# Processing Record 19 of Set 7 | abomey
# Processing Record 20 of Set 7 | pacific grove
# Processing Record 21 of Set 7 | maridi
# Processing Record 22 of Set 7 | half moon bay
# Processing Record 23 of Set 7 | mount isa
# Processing Record 24 of Set 7 | labuhan
# Processing Record 25 of Set 7 | mapiripan
# Processing Record 26 of Set 7 | fortuna
# Processing Record 27 of Set 7 | mamallapuram
# Processing Record 28 of Set 7 | adre
# Processing Record 29 of Set 7 | arlit
# Processing Record 30 of Set 7 | bom jesus
# Processing Record 31 of Set 7 | kaoma
# Processing Record 32 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 7 | ellisras
# Processing Record 34 of Set 7 | prata
# Processing Record 35 of Set 7 | safaga
# Processing Record 36 of Set 7 | bodden town
# Processing Record 37 of Set 7 | montijo
# Processing Record 38 of Set 7 | pangnirtung
# Processing Record 39 of Set 7 | arona
# Processing Record 40 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 7 | tapejara
# Processing Record 42 of Set 7 | cherskiy
# Processing Record 43 of Set 7 | sibut
# Processing Record 44 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 7 | camocim
# Processing Record 46 of Set 7 | yalta
# Processing Record 47 of Set 7 | hamilton
# Processing Record 48 of Set 7 | mae hong son
# Processing Record 49 of Set 7 | vila
# Processing Record 50 of Set 7 | tura
# Processing Record 1 of Set 8 | matara
# Processing Record 2 of Set 8 | port elizabeth
# Processing Record 3 of Set 8 | wahlstedt
# Processing Record 4 of Set 8 | clarksburg
# Processing Record 5 of Set 8 | whyalla
# Processing Record 6 of Set 8 | santa cruz de la palma
# Processing Record 7 of Set 8 | lebu
# Processing Record 8 of Set 8 | laguna
# Processing Record 9 of Set 8 | kodiak
# Processing Record 10 of Set 8 | lorengau
# Processing Record 11 of Set 8 | pangkalanbuun
# Processing Record 12 of Set 8 | sambava
# Processing Record 13 of Set 8 | yangambi
# Processing Record 14 of Set 8 | benguela
# Processing Record 15 of Set 8 | sao joao do paraiso
# Processing Record 16 of Set 8 | harboore
# Processing Record 17 of Set 8 | amberley
# Processing Record 18 of Set 8 | cabedelo
# Processing Record 19 of Set 8 | tabuk
# Processing Record 20 of Set 8 | lata
# Processing Record 21 of Set 8 | tiarei
# Processing Record 22 of Set 8 | doha
# Processing Record 23 of Set 8 | morro bay
# Processing Record 24 of Set 8 | bereda
# Processing Record 25 of Set 8 | awbari
# Processing Record 26 of Set 8 | winona
# Processing Record 27 of Set 8 | padang
# Processing Record 28 of Set 8 | puerto ayacucho
# Processing Record 29 of Set 8 | maluso
# Processing Record 30 of Set 8 | kasongo-lunda
# Processing Record 31 of Set 8 | inhambane
# Processing Record 32 of Set 8 | kamina
# Processing Record 33 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 8 | popondetta
# Processing Record 35 of Set 8 | faya
# Processing Record 36 of Set 8 | key largo
# Processing Record 37 of Set 8 | katha
# City not found. Skipping...
# Processing Record 38 of Set 8 | nizhnevartovsk
# Processing Record 39 of Set 8 | gat
# Processing Record 40 of Set 8 | ambon
# Processing Record 41 of Set 8 | srednekolymsk
# Processing Record 42 of Set 8 | ulaangom
# Processing Record 43 of Set 8 | salalah
# Processing Record 44 of Set 8 | rafaela
# Processing Record 45 of Set 8 | hasaki
# Processing Record 46 of Set 8 | karratha
# Processing Record 47 of Set 8 | kenai
# Processing Record 48 of Set 8 | valdivia
# Processing Record 49 of Set 8 | abu samrah
# Processing Record 50 of Set 8 | aklavik
# Processing Record 1 of Set 9 | pontianak
# Processing Record 2 of Set 9 | xiangxiang
# Processing Record 3 of Set 9 | te anau
# Processing Record 4 of Set 9 | marsa matruh
# Processing Record 5 of Set 9 | saldanha
# Processing Record 6 of Set 9 | yuzhnyy
# Processing Record 7 of Set 9 | mount gambier
# Processing Record 8 of Set 9 | paranga
# Processing Record 9 of Set 9 | namatanai
# Processing Record 10 of Set 9 | codrington
# Processing Record 11 of Set 9 | marietta
# Processing Record 12 of Set 9 | axim
# Processing Record 13 of Set 9 | irbil
# Processing Record 14 of Set 9 | azangaro
# Processing Record 15 of Set 9 | bubaque
# Processing Record 16 of Set 9 | puerto carreno
# Processing Record 17 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 9 | norsup
# Processing Record 19 of Set 9 | paro
# Processing Record 20 of Set 9 | aksarka
# Processing Record 21 of Set 9 | college
# Processing Record 22 of Set 9 | derzhavinsk
# Processing Record 23 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 9 | manoharpur
# Processing Record 25 of Set 9 | baoro
# Processing Record 26 of Set 9 | seddon
# Processing Record 27 of Set 9 | nkowakowa
# Processing Record 28 of Set 9 | sibiti
# Processing Record 29 of Set 9 | malanje
# Processing Record 30 of Set 9 | dukat
# Processing Record 31 of Set 9 | floro
# Processing Record 32 of Set 9 | el jicaro
# Processing Record 33 of Set 9 | wilmington
# Processing Record 34 of Set 9 | borogontsy
# Processing Record 35 of Set 9 | svarstad
# Processing Record 36 of Set 9 | kihei
# Processing Record 37 of Set 9 | comodoro rivadavia
# Processing Record 38 of Set 9 | ripoll
# Processing Record 39 of Set 9 | sinnar
# Processing Record 40 of Set 9 | beloha
# Processing Record 41 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 9 | innisfail
# Processing Record 43 of Set 9 | solnechnyy
# Processing Record 44 of Set 9 | casa grande
# Processing Record 45 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 9 | polis
# Processing Record 47 of Set 9 | antofagasta
# Processing Record 48 of Set 9 | vredendal
# Processing Record 49 of Set 9 | lac-megantic
# Processing Record 50 of Set 9 | pombas
# Processing Record 1 of Set 10 | cap-haitien
# Processing Record 2 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 10 | torbay
# Processing Record 4 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 10 | araouane
# Processing Record 6 of Set 10 | ancud
# Processing Record 7 of Set 10 | elsfleth
# Processing Record 8 of Set 10 | abalak
# Processing Record 9 of Set 10 | sao joao da barra
# Processing Record 10 of Set 10 | lins
# Processing Record 11 of Set 10 | palana
# Processing Record 12 of Set 10 | san jose
# Processing Record 13 of Set 10 | caldas novas
# Processing Record 14 of Set 10 | gazanjyk
# Processing Record 15 of Set 10 | mingrelskaya
# Processing Record 16 of Set 10 | la romana
# Processing Record 17 of Set 10 | olavarria
# Processing Record 18 of Set 10 | cidreira
# Processing Record 19 of Set 10 | san policarpo
# Processing Record 20 of Set 10 | beecher
# Processing Record 21 of Set 10 | puerto escondido
# Processing Record 22 of Set 10 | kodinsk
# Processing Record 23 of Set 10 | taoudenni
# Processing Record 24 of Set 10 | zhanaozen
# Processing Record 25 of Set 10 | vilcun
# Processing Record 26 of Set 10 | najran
# Processing Record 27 of Set 10 | tacoronte
# Processing Record 28 of Set 10 | batagay-alyta
# Processing Record 29 of Set 10 | lucapa
# Processing Record 30 of Set 10 | asau
# Processing Record 31 of Set 10 | horsham
# Processing Record 32 of Set 10 | nalut
# Processing Record 33 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 10 | san angelo
# Processing Record 35 of Set 10 | empa
# City not found. Skipping...
# Processing Record 36 of Set 10 | zhangye
# Processing Record 37 of Set 10 | chabahar
# Processing Record 38 of Set 10 | burkhala
# City not found. Skipping...
# Processing Record 39 of Set 10 | bathsheba
# Processing Record 40 of Set 10 | chicama
# Processing Record 41 of Set 10 | kamenka
# Processing Record 42 of Set 10 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 43 of Set 10 | puerto colombia
# Processing Record 44 of Set 10 | bail hongal
# Processing Record 45 of Set 10 | wanning
# Processing Record 46 of Set 10 | marystown
# Processing Record 47 of Set 10 | achi
# Processing Record 48 of Set 10 | katangli
# Processing Record 49 of Set 10 | sola
# Processing Record 50 of Set 10 | mahon
# Processing Record 1 of Set 11 | hirara
# Processing Record 2 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 3 of Set 11 | port hardy
# Processing Record 4 of Set 11 | noto
# Processing Record 5 of Set 11 | geraldton
# Processing Record 6 of Set 11 | cumpas
# Processing Record 7 of Set 11 | ambilobe
# Processing Record 8 of Set 11 | ochamchira
# Processing Record 9 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 10 of Set 11 | elko
# Processing Record 11 of Set 11 | tautira
# Processing Record 12 of Set 11 | saint-francois
# Processing Record 13 of Set 11 | tulun
# Processing Record 14 of Set 11 | lubango
# Processing Record 15 of Set 11 | murdochville
# Processing Record 16 of Set 11 | itoman
# Processing Record 17 of Set 11 | parauna
# Processing Record 18 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 19 of Set 11 | aljezur
# Processing Record 20 of Set 11 | la palma
# Processing Record 21 of Set 11 | ikongo
# Processing Record 22 of Set 11 | hovd
# Processing Record 23 of Set 11 | klyuchi
# Processing Record 24 of Set 11 | fukue
# Processing Record 25 of Set 11 | qaqortoq
# Processing Record 26 of Set 11 | rezina
# Processing Record 27 of Set 11 | tolaga bay
# Processing Record 28 of Set 11 | tortoli
# Processing Record 29 of Set 11 | nuuk
# Processing Record 30 of Set 11 | turukhansk
# Processing Record 31 of Set 11 | swift current
# Processing Record 32 of Set 11 | berdigestyakh
# Processing Record 33 of Set 11 | sakaiminato
# Processing Record 34 of Set 11 | inirida
# Processing Record 35 of Set 11 | novosokolniki
# Processing Record 36 of Set 11 | ulagan
# Processing Record 37 of Set 11 | richards bay
# Processing Record 38 of Set 11 | tandalti
# Processing Record 39 of Set 11 | pozo colorado
# Processing Record 40 of Set 11 | atambua
# Processing Record 41 of Set 11 | baherden
# Processing Record 42 of Set 11 | mukhen
# Processing Record 43 of Set 11 | cotonou
# Processing Record 44 of Set 11 | phan thiet
# Processing Record 45 of Set 11 | taiobeiras
# Processing Record 46 of Set 11 | juba
# Processing Record 47 of Set 11 | ishigaki
# Processing Record 48 of Set 11 | irbeyskoye
# Processing Record 49 of Set 11 | pudozh
# Processing Record 50 of Set 11 | palmas
# Processing Record 1 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 2 of Set 12 | alofi
# Processing Record 3 of Set 12 | taguatinga
# Processing Record 4 of Set 12 | beipiao
# Processing Record 5 of Set 12 | ekhabi
# Processing Record 6 of Set 12 | lovozero
# Processing Record 7 of Set 12 | hattiesburg
# Processing Record 8 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 12 | bowen
# Processing Record 10 of Set 12 | sao jose da coroa grande
# Processing Record 11 of Set 12 | sauda
# Processing Record 12 of Set 12 | negombo
# Processing Record 13 of Set 12 | tilichiki
# Processing Record 14 of Set 12 | careiro da varzea
# Processing Record 15 of Set 12 | vangaindrano
# Processing Record 16 of Set 12 | marawi
# Processing Record 17 of Set 12 | itanagar
# Processing Record 18 of Set 12 | ruteng
# Processing Record 19 of Set 12 | zhigansk
# Processing Record 20 of Set 12 | kahului
# Processing Record 21 of Set 12 | ohara
# Processing Record 22 of Set 12 | mae chan
# Processing Record 23 of Set 12 | guerrero
# Processing Record 24 of Set 12 | maragogi
# Processing Record 25 of Set 12 | ranong
# Processing Record 26 of Set 12 | gulu
# Processing Record 27 of Set 12 | carutapera
# Processing Record 28 of Set 12 | timizart
# Processing Record 29 of Set 12 | havelock
# Processing Record 30 of Set 12 | egvekinot
# Processing Record 31 of Set 12 | micheweni
# Processing Record 32 of Set 12 | naze
# Processing Record 33 of Set 12 | pemberton
# Processing Record 34 of Set 12 | lashio
# Processing Record 35 of Set 12 | sumbe
# Processing Record 36 of Set 12 | wilkie
# Processing Record 37 of Set 12 | akureyri
# Processing Record 38 of Set 12 | dingzhou
# Processing Record 39 of Set 12 | ushtobe
# Processing Record 40 of Set 12 | gobabis
# Processing Record 41 of Set 12 | havoysund
# Processing Record 42 of Set 12 | camacha
# Processing Record 43 of Set 12 | kidal
# Processing Record 44 of Set 12 | nisia floresta
# Processing Record 45 of Set 12 | mega
# Processing Record 46 of Set 12 | tigil
# Processing Record 47 of Set 12 | snezhnogorsk
# Processing Record 48 of Set 12 | bourail
# Processing Record 49 of Set 12 | san patricio
# Processing Record 50 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 1 of Set 13 | cuyo
# Processing Record 2 of Set 13 | ilo
# Processing Record 3 of Set 13 | chernyshevskiy
# Processing Record 4 of Set 13 | morozovsk
# Processing Record 5 of Set 13 | omaruru
# Processing Record 6 of Set 13 | surgut
# Processing Record 7 of Set 13 | uddevalla
# Processing Record 8 of Set 13 | vanavara
# Processing Record 9 of Set 13 | kabalo
# Processing Record 10 of Set 13 | fort nelson
# Processing Record 11 of Set 13 | kropotkin
# Processing Record 12 of Set 13 | lavumisa
# Processing Record 13 of Set 13 | luis correia
# Processing Record 14 of Set 13 | ashland
# Processing Record 15 of Set 13 | acapulco
# Processing Record 16 of Set 13 | sur
# Processing Record 17 of Set 13 | mayo
# Processing Record 18 of Set 13 | ribeira brava
# Processing Record 19 of Set 13 | san andres
# Processing Record 20 of Set 13 | unai
# Processing Record 21 of Set 13 | aktas
# Processing Record 22 of Set 13 | kushima
# Processing Record 23 of Set 13 | borisoglebskiy
# Processing Record 24 of Set 13 | pathardi
# Processing Record 25 of Set 13 | olinda
# Processing Record 26 of Set 13 | sidney
# Processing Record 27 of Set 13 | nouadhibou
# Processing Record 28 of Set 13 | pyshchug
# Processing Record 29 of Set 13 | springbok
# Processing Record 30 of Set 13 | panaba
# Processing Record 31 of Set 13 | port-cartier
# Processing Record 32 of Set 13 | marzuq
# Processing Record 33 of Set 13 | anchorage
# Processing Record 34 of Set 13 | gravata
# Processing Record 35 of Set 13 | conceicao do araguaia
# Processing Record 36 of Set 13 | markala
# Processing Record 37 of Set 13 | maniitsoq
# Processing Record 38 of Set 13 | shelburne
# Processing Record 39 of Set 13 | san quintin
# Processing Record 40 of Set 13 | port lincoln
# Processing Record 41 of Set 13 | catamarca
# Processing Record 42 of Set 13 | kutahya
# Processing Record 43 of Set 13 | handwara
# City not found. Skipping...
# Processing Record 44 of Set 13 | oudtshoorn
# Processing Record 45 of Set 13 | ji-parana
# City not found. Skipping...
# Processing Record 46 of Set 13 | zyryanka
# Processing Record 47 of Set 13 | santa maria
# Processing Record 48 of Set 13 | touros
# Processing Record 49 of Set 13 | funadhoo
# Processing Record 50 of Set 13 | cozumel
# Processing Record 1 of Set 14 | juneau
# Processing Record 2 of Set 14 | buluang
# Processing Record 3 of Set 14 | flinders
# Processing Record 4 of Set 14 | payo
# Processing Record 5 of Set 14 | south lake tahoe
# Processing Record 6 of Set 14 | cairns
# Processing Record 7 of Set 14 | general roca
# Processing Record 8 of Set 14 | camacupa
# Processing Record 9 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 10 of Set 14 | pangai
# Processing Record 11 of Set 14 | mangrol
# Processing Record 12 of Set 14 | muyezerskiy
# Processing Record 13 of Set 14 | la ronge
# Processing Record 14 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 14 | kwinana
# Processing Record 16 of Set 14 | along
# Processing Record 17 of Set 14 | langsa
# Processing Record 18 of Set 14 | podgorica
# Processing Record 19 of Set 14 | port shepstone
# Processing Record 20 of Set 14 | ust-koksa
# Processing Record 21 of Set 14 | grindavik
# Processing Record 22 of Set 14 | igarka
# Processing Record 23 of Set 14 | yanam
# Processing Record 24 of Set 14 | de aar
# Processing Record 25 of Set 14 | hede
# Processing Record 26 of Set 14 | caraballeda
# Processing Record 27 of Set 14 | hit
# Processing Record 28 of Set 14 | ariquemes
# Processing Record 29 of Set 14 | jaciara
# Processing Record 30 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 31 of Set 14 | tuy hoa
# Processing Record 32 of Set 14 | dedza
# Processing Record 33 of Set 14 | dickinson
# Processing Record 34 of Set 14 | penzance
# Processing Record 35 of Set 14 | cascais
# Processing Record 36 of Set 14 | gonbad-e qabus
# Processing Record 37 of Set 14 | miles city
# Processing Record 38 of Set 14 | whitehorse
# Processing Record 39 of Set 14 | sioux lookout
# Processing Record 40 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 41 of Set 14 | singaraja
# Processing Record 42 of Set 14 | nuevo progreso
# Processing Record 43 of Set 14 | berbera
# Processing Record 44 of Set 14 | taitung
# Processing Record 45 of Set 14 | waingapu
# Processing Record 46 of Set 14 | belaya gora
# Processing Record 47 of Set 14 | ponta delgada
# Processing Record 48 of Set 14 | seoul
# Processing Record 49 of Set 14 | edd
# Processing Record 50 of Set 14 | padilla
# Processing Record 1 of Set 15 | acari
# Processing Record 2 of Set 15 | cortez
# Processing Record 3 of Set 15 | imeni stepana razina
# Processing Record 4 of Set 15 | dunmore east
# Processing Record 5 of Set 15 | portland
# Processing Record 6 of Set 15 | vila velha
# Processing Record 7 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 8 of Set 15 | coquimbo
# Processing Record 9 of Set 15 | qui nhon
# Processing Record 10 of Set 15 | solginskiy
# Processing Record 11 of Set 15 | catuday
# Processing Record 12 of Set 15 | lima
# Processing Record 13 of Set 15 | narasannapeta
# Processing Record 14 of Set 15 | alpena
# Processing Record 15 of Set 15 | nizwa
# Processing Record 16 of Set 15 | marevo
# Processing Record 17 of Set 15 | taltal
# Processing Record 18 of Set 15 | tuatapere
# Processing Record 19 of Set 15 | tandil
# Processing Record 20 of Set 15 | alyangula
# Processing Record 21 of Set 15 | krasnogorskoye
# Processing Record 22 of Set 15 | mugreyevskiy
# City not found. Skipping...
# Processing Record 23 of Set 15 | maningrida
# Processing Record 24 of Set 15 | yakeshi
# Processing Record 25 of Set 15 | port hedland
# Processing Record 26 of Set 15 | berlevag
# Processing Record 27 of Set 15 | ati
# Processing Record 28 of Set 15 | chardara
# Processing Record 29 of Set 15 | saint-pierre
# Processing Record 30 of Set 15 | mogadishu
# Processing Record 31 of Set 15 | doctor arroyo
# Processing Record 32 of Set 15 | ola
# Processing Record 33 of Set 15 | gberia fotombu
# Processing Record 34 of Set 15 | buin
# Processing Record 35 of Set 15 | yeppoon
# Processing Record 36 of Set 15 | jamsa
# Processing Record 37 of Set 15 | bressuire
# Processing Record 38 of Set 15 | fundacion
# Processing Record 39 of Set 15 | menongue
# Processing Record 40 of Set 15 | hibbing
# Processing Record 41 of Set 15 | mahibadhoo
# Processing Record 42 of Set 15 | bologoye
# Processing Record 43 of Set 15 | opotiki
# Processing Record 44 of Set 15 | asheville
# Processing Record 45 of Set 15 | rock springs
# Processing Record 46 of Set 15 | paraisopolis
# Processing Record 47 of Set 15 | skowhegan
# Processing Record 48 of Set 15 | potsdam
# Processing Record 49 of Set 15 | champerico
# Processing Record 50 of Set 15 | coulihaut
# City not found. Skipping...
# Processing Record 1 of Set 16 | svobodnyy
# Processing Record 2 of Set 16 | cobija
# Processing Record 3 of Set 16 | ciudad bolivar
# Processing Record 4 of Set 16 | boguchany
# Processing Record 5 of Set 16 | kloulklubed
# Processing Record 6 of Set 16 | gorontalo
# Processing Record 7 of Set 16 | tochio
# Processing Record 8 of Set 16 | zhaozhou
# Processing Record 9 of Set 16 | antigonish
# Processing Record 10 of Set 16 | bay roberts
# Processing Record 11 of Set 16 | shingu
# Processing Record 12 of Set 16 | larsnes
# Processing Record 13 of Set 16 | norman wells
# Processing Record 14 of Set 16 | mizdah
# Processing Record 15 of Set 16 | limbang
# Processing Record 16 of Set 16 | gillette
# Processing Record 17 of Set 16 | stepnyak
# Processing Record 18 of Set 16 | margate
# Processing Record 19 of Set 16 | tual
# Processing Record 20 of Set 16 | nizhnyaya tavda
# Processing Record 21 of Set 16 | nioro
# Processing Record 22 of Set 16 | kichera
# Processing Record 23 of Set 16 | nyurba
# Processing Record 24 of Set 16 | ugoofaaru
# Processing Record 25 of Set 16 | puerto baquerizo moreno
# Processing Record 26 of Set 16 | losinyy
# Processing Record 27 of Set 16 | rafraf
# Processing Record 28 of Set 16 | corinto
# Processing Record 29 of Set 16 | lusk
# Processing Record 30 of Set 16 | mgachi
# Processing Record 31 of Set 16 | farafangana
# Processing Record 32 of Set 16 | mariental
# Processing Record 33 of Set 16 | lydenburg
# Processing Record 34 of Set 16 | flagstaff
# Processing Record 35 of Set 16 | gombong
# Processing Record 36 of Set 16 | suntar
# Processing Record 37 of Set 16 | pochutla
# Processing Record 38 of Set 16 | iisalmi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0      Esperance      AU -33.8667  121.9000     48.43        74           0
# 1            Fez      MA  34.0372   -4.9998     80.85        50          40
# 2     Walvis Bay      NA -22.9575   14.5053     58.15        77           0
# 3           Hilo      US  19.7297 -155.0900     86.29        93         100
# 4       Tshikapa      CD  -6.4167   20.8000     75.40        36           2
# 5      Ketchikan      US  55.3422 -131.6461     72.07        60           0
# 6  Leningradskiy      RU  69.3833  178.4167     47.03        76          93
# 7         Dikson      RU  73.5069   80.5464     31.95        96          79
# 8       Estreito      BR  -5.7833  -43.2500     84.92        46          15
# 9    New Norfolk      AU -42.7826  147.0587     42.91        86          76
#
#    Wind Speed Current Description
# 0       13.87           clear sky
# 1        9.22  light thunderstorm
# 2        0.00           clear sky
# 3       12.66       moderate rain
# 4        2.26           clear sky
# 5       10.36           clear sky
# 6        4.65     overcast clouds
# 7        7.63       broken clouds
# 8        1.83          few clouds
# 9        1.99       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
